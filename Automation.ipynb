# %% [markdown]
# ## Automation
# Nothing too fancy here.

# %%
# !jupyter nbconvert --to python source/__init__.ipynb
# !jupyter nbconvert --to python source/chain.ipynb
# !jupyter nbconvert --to python source/magic.ipynb
# !cp source/__init__.py whatever4e/__init__.py
# !cp source/magic.py whatever4e/magic.py
# !cp source/chain.py whatever4e/chain.py
# !cp source/class_maker.py whatever4e/class_maker.py

# !jupyter nbconvert --to rst source/__init__.ipynb
# !cp source/__init__.rst README.rst

# !python setup.py install
# Out:
# [NbConvertApp] Converting notebook source/__init__.ipynb to python
# [NbConvertApp] Writing 1625 bytes to source/__init__.py
# [NbConvertApp] Converting notebook source/chain.ipynb to python
# [NbConvertApp] Writing 4551 bytes to source/chain.py
# [NbConvertApp] Converting notebook source/magic.ipynb to python
# [NbConvertApp] Writing 2780 bytes to source/magic.py
# [NbConvertApp] Converting notebook source/__init__.ipynb to rst
# [NbConvertApp] Writing 1720 bytes to source/__init__.rst
# running install
# running bdist_egg
# running egg_info
# writing dependency_links to whatever4e.egg-info/dependency_links.txt
# writing requirements to whatever4e.egg-info/requires.txt
# writing whatever4e.egg-info/PKG-INFO
# writing top-level names to whatever4e.egg-info/top_level.txt
# file whatever4e.py (for module whatever4e) not found
# reading manifest file 'whatever4e.egg-info/SOURCES.txt'
# reading manifest template 'MANIFEST.in'
# warning: no files found matching '*.ipynb' under directory 'tests/'
# writing manifest file 'whatever4e.egg-info/SOURCES.txt'
# installing library code to build/bdist.macosx-10.5-x86_64/egg
# running install_lib
# running build_py
# file whatever4e.py (for module whatever4e) not found
# file whatever4e.py (for module whatever4e) not found
# creating build/bdist.macosx-10.5-x86_64/egg
# copying build/lib/whatever4e.py -> build/bdist.macosx-10.5-x86_64/egg
# byte-compiling build/bdist.macosx-10.5-x86_64/egg/whatever4e.py to whatever4e.cpython-35.pyc
# creating build/bdist.macosx-10.5-x86_64/egg/EGG-INFO
# copying whatever4e.egg-info/PKG-INFO -> build/bdist.macosx-10.5-x86_64/egg/EGG-INFO
# copying whatever4e.egg-info/SOURCES.txt -> build/bdist.macosx-10.5-x86_64/egg/EGG-INFO
# copying whatever4e.egg-info/dependency_links.txt -> build/bdist.macosx-10.5-x86_64/egg/EGG-INFO
# copying whatever4e.egg-info/requires.txt -> build/bdist.macosx-10.5-x86_64/egg/EGG-INFO
# copying whatever4e.egg-info/top_level.txt -> build/bdist.macosx-10.5-x86_64/egg/EGG-INFO
# zip_safe flag not set; analyzing archive contents...
# creating 'dist/whatever4e-0.2.0-py3.5.egg' and adding 'build/bdist.macosx-10.5-x86_64/egg' to it
# removing 'build/bdist.macosx-10.5-x86_64/egg' (and everything under it)
# Processing whatever4e-0.2.0-py3.5.egg
# Removing /Users/tfast/anaconda/lib/python3.5/site-packages/whatever4e-0.2.0-py3.5.egg
# Copying whatever4e-0.2.0-py3.5.egg to /Users/tfast/anaconda/lib/python3.5/site-packages
# whatever4e 0.2.0 is already the active version in easy-install.pth
#
# Installed /Users/tfast/anaconda/lib/python3.5/site-packages/whatever4e-0.2.0-py3.5.egg
# Processing dependencies for whatever4e==0.2.0
# Searching for toolz==0.8.0
# Best match: toolz 0.8.0
# Adding toolz 0.8.0 to easy-install.pth file
#
# Using /Users/tfast/anaconda/lib/python3.5/site-packages
# Finished processing dependencies for whatever4e==0.2.0

# %%
# %%file setup.py
import os
from setuptools import setup


def read(fname):
    """
    Utility function to read the README file.
    Used for the long_description.  It's nice, because now 1) we have a top
    level README file and 2) it's easier to type in the README file than to put
    a raw string in below ...
    """
    with open(os.path.join(os.path.dirname(__file__), fname)) as f:
        return f.read()


setup(
    name="whatever4e",
    version="0.2.0",
    author="Tony Fast",
    author_email="tony.fast@gmail.com",
    description="prototype whatever in the Jupyter notebook",
    license="BSD",
    keywords="IPython Magic Jupyter",
    url="http://github.com/tonyfast/whatever-forever",
    py_modules=["whatever4e"],
    long_description=read("README.rst"),
    classifiers=[
        "Topic :: Utilities",
        "Framework :: IPython",
        "Natural Language :: English",
        "Programming Language :: Python",
        "Intended Audience :: Developers",
        "Development Status :: 3 - Alpha",
        "Operating System :: OS Independent",
        "Programming Language :: Python :: 3",
        "License :: OSI Approved :: BSD License",
        "Topic :: Software Development :: Testing",
    ],
    install_requires=[
        "toolz",
    ]
)
# Out:
# Overwriting setup.py

# %% [markdown]
# ### Run tests

# %%
# !python setup.py test

# %% [markdown]
# ### Check code style

# %%
# !flake8
# Out:
# ./setup.py:42:2: W292 no newline at end of file
# ./whatever4e.py:15:1: F403 'from toolz.curried import *' used; unable to detect undefined names
# ./whatever4e.py:28:2: W291 trailing whitespace
# ./whatever4e.py:29:80: E501 line too long (112 > 79 characters)
# ./whatever4e.py:30:2: W291 trailing whitespace
# ./whatever4e.py:31:2: W291 trailing whitespace
# ./whatever4e.py:33:2: W291 trailing whitespace
# ./whatever4e.py:34:80: E501 line too long (190 > 79 characters)
# ./whatever4e.py:37:2: W291 trailing whitespace
# ./whatever4e.py:39:2: W291 trailing whitespace
# ./whatever4e.py:41:2: W291 trailing whitespace
# ./whatever4e.py:43:2: W291 trailing whitespace
# ./whatever4e.py:60:80: E501 line too long (82 > 79 characters)
# ./whatever4e.py:65:40: W291 trailing whitespace
# ./whatever4e.py:67:13: E124 closing bracket does not match visual indentation
# ./whatever4e.py:72:1: W293 blank line contains whitespace
# ./whatever4e.py:76:1: W293 blank line contains whitespace
# ./whatever4e.py:81:1: W293 blank line contains whitespace
# ./whatever4e.py:90:1: W293 blank line contains whitespace
# ./whatever4e.py:91:5: E303 too many blank lines (2)
# ./whatever4e.py:117:1: W293 blank line contains whitespace
# ./whatever4e.py:119:1: W293 blank line contains whitespace
# ./whatever4e.py:122:42: W291 trailing whitespace
# ./whatever4e.py:123:1: W293 blank line contains whitespace
# ./whatever4e.py:126:1: W293 blank line contains whitespace
# ./whatever4e.py:131:2: W291 trailing whitespace
# ./whatever4e.py:132:80: E501 line too long (113 > 79 characters)
# ./whatever4e.py:132:114: W291 trailing whitespace
# ./whatever4e.py:133:80: E501 line too long (121 > 79 characters)
# ./whatever4e.py:134:2: W291 trailing whitespace
# ./whatever4e.py:135:80: E501 line too long (113 > 79 characters)
# ./whatever4e.py:136:80: E501 line too long (118 > 79 characters)
# ./whatever4e.py:146:1: E302 expected 2 blank lines, found 0
# ./whatever4e.py:151:1: W293 blank line contains whitespace
# ./whatever4e.py:155:22: W291 trailing whitespace
# ./whatever4e.py:160:19: W291 trailing whitespace
# ./whatever4e.py:162:1: W293 blank line contains whitespace
# ./whatever4e.py:168:80: E501 line too long (80 > 79 characters)
# ./whatever4e.py:173:1: W293 blank line contains whitespace
# ./whatever4e.py:177:1: W293 blank line contains whitespace
# ./whatever4e.py:181:1: W293 blank line contains whitespace
# ./whatever4e.py:186:1: W293 blank line contains whitespace
# ./whatever4e.py:200:1: W293 blank line contains whitespace
# ./whatever4e.py:205:1: W391 blank line at end of file
# ./build/lib/whatever4e.py:15:1: F403 'from toolz.curried import *' used; unable to detect undefined names
# ./build/lib/whatever4e.py:28:2: W291 trailing whitespace
# ./build/lib/whatever4e.py:29:80: E501 line too long (112 > 79 characters)
# ./build/lib/whatever4e.py:30:2: W291 trailing whitespace
# ./build/lib/whatever4e.py:31:2: W291 trailing whitespace
# ./build/lib/whatever4e.py:33:2: W291 trailing whitespace
# ./build/lib/whatever4e.py:34:80: E501 line too long (190 > 79 characters)
# ./build/lib/whatever4e.py:37:2: W291 trailing whitespace
# ./build/lib/whatever4e.py:39:2: W291 trailing whitespace
# ./build/lib/whatever4e.py:41:2: W291 trailing whitespace
# ./build/lib/whatever4e.py:43:2: W291 trailing whitespace
# ./build/lib/whatever4e.py:60:80: E501 line too long (82 > 79 characters)
# ./build/lib/whatever4e.py:65:40: W291 trailing whitespace
# ./build/lib/whatever4e.py:67:13: E124 closing bracket does not match visual indentation
# ./build/lib/whatever4e.py:72:1: W293 blank line contains whitespace
# ./build/lib/whatever4e.py:76:1: W293 blank line contains whitespace
# ./build/lib/whatever4e.py:81:1: W293 blank line contains whitespace
# ./build/lib/whatever4e.py:90:1: W293 blank line contains whitespace
# ./build/lib/whatever4e.py:91:5: E303 too many blank lines (2)
# ./build/lib/whatever4e.py:117:1: W293 blank line contains whitespace
# ./build/lib/whatever4e.py:119:1: W293 blank line contains whitespace
# ./build/lib/whatever4e.py:122:42: W291 trailing whitespace
# ./build/lib/whatever4e.py:123:1: W293 blank line contains whitespace
# ./build/lib/whatever4e.py:126:1: W293 blank line contains whitespace
# ./build/lib/whatever4e.py:131:2: W291 trailing whitespace
# ./build/lib/whatever4e.py:132:80: E501 line too long (113 > 79 characters)
# ./build/lib/whatever4e.py:132:114: W291 trailing whitespace
# ./build/lib/whatever4e.py:133:80: E501 line too long (121 > 79 characters)
# ./build/lib/whatever4e.py:134:2: W291 trailing whitespace
# ./build/lib/whatever4e.py:135:80: E501 line too long (113 > 79 characters)
# ./build/lib/whatever4e.py:136:80: E501 line too long (118 > 79 characters)
# ./build/lib/whatever4e.py:146:1: E302 expected 2 blank lines, found 0
# ./build/lib/whatever4e.py:151:1: W293 blank line contains whitespace
# ./build/lib/whatever4e.py:155:22: W291 trailing whitespace
# ./build/lib/whatever4e.py:160:19: W291 trailing whitespace
# ./build/lib/whatever4e.py:162:1: W293 blank line contains whitespace
# ./build/lib/whatever4e.py:168:80: E501 line too long (80 > 79 characters)
# ./build/lib/whatever4e.py:173:1: W293 blank line contains whitespace
# ./build/lib/whatever4e.py:177:1: W293 blank line contains whitespace
# ./build/lib/whatever4e.py:181:1: W293 blank line contains whitespace
# ./build/lib/whatever4e.py:186:1: W293 blank line contains whitespace
# ./build/lib/whatever4e.py:200:1: W293 blank line contains whitespace
# ./build/lib/whatever4e.py:212:1: E303 too many blank lines (4)
# ./build/lib/whatever4e.py:215:1: W391 blank line at end of file

# %% [markdown]
# ### Generate `README.md` from `README.ipynb`

# %%
# !jupyter nbconvert README.ipynb --to=markdown
# Out:
# [NbConvertApp] Converting notebook README.ipynb to markdown
# [NbConvertApp] Writing 2409 bytes to README.md

# %% [markdown]
# ## Test Release for PyPi

# %%
# !python setup.py register -r pypitest
# !python setup.py sdist
# !python setup.py bdist_wheel
# !python setup.py sdist upload -r pypitest
# !python setup.py bdist_wheel upload -r pypitest
# Out:
# running register
# running egg_info
# writing dependency_links to whatever4e.egg-info/dependency_links.txt
# writing top-level names to whatever4e.egg-info/top_level.txt
# writing requirements to whatever4e.egg-info/requires.txt
# writing whatever4e.egg-info/PKG-INFO
# reading manifest file 'whatever4e.egg-info/SOURCES.txt'
# reading manifest template 'MANIFEST.in'
# warning: no files found matching '*.ipynb' under directory 'tests/'
# writing manifest file 'whatever4e.egg-info/SOURCES.txt'
# running check
# Registering whatever4e to https://testpypi.python.org/pypi
# Server response (200): OK
# running sdist
# running egg_info
# writing whatever4e.egg-info/PKG-INFO
# writing requirements to whatever4e.egg-info/requires.txt
# writing top-level names to whatever4e.egg-info/top_level.txt
# writing dependency_links to whatever4e.egg-info/dependency_links.txt
# reading manifest file 'whatever4e.egg-info/SOURCES.txt'
# reading manifest template 'MANIFEST.in'
# warning: no files found matching '*.ipynb' under directory 'tests/'
# writing manifest file 'whatever4e.egg-info/SOURCES.txt'
# running check
# creating whatever4e-0.2.0
# creating whatever4e-0.2.0/whatever4e.egg-info
# making hard links in whatever4e-0.2.0...
# hard linking Automation.ipynb -> whatever4e-0.2.0
# hard linking LICENSE -> whatever4e-0.2.0
# hard linking MANIFEST.in -> whatever4e-0.2.0
# hard linking README.ipynb -> whatever4e-0.2.0
# hard linking README.md -> whatever4e-0.2.0
# hard linking README.rst -> whatever4e-0.2.0
# hard linking setup.cfg -> whatever4e-0.2.0
# hard linking setup.py -> whatever4e-0.2.0
# hard linking whatever4e.ipynb -> whatever4e-0.2.0
# hard linking whatever4e.py -> whatever4e-0.2.0
# hard linking whatever4e.egg-info/PKG-INFO -> whatever4e-0.2.0/whatever4e.egg-info
# hard linking whatever4e.egg-info/SOURCES.txt -> whatever4e-0.2.0/whatever4e.egg-info
# hard linking whatever4e.egg-info/dependency_links.txt -> whatever4e-0.2.0/whatever4e.egg-info
# hard linking whatever4e.egg-info/requires.txt -> whatever4e-0.2.0/whatever4e.egg-info
# hard linking whatever4e.egg-info/top_level.txt -> whatever4e-0.2.0/whatever4e.egg-info
# copying setup.cfg -> whatever4e-0.2.0
# Writing whatever4e-0.2.0/setup.cfg
# Creating tar archive
# removing 'whatever4e-0.2.0' (and everything under it)
# running bdist_wheel
# running build
# running build_py
# copying whatever4e.py -> build/lib
# installing to build/bdist.macosx-10.5-x86_64/wheel
# running install
# running install_lib
# creating build/bdist.macosx-10.5-x86_64/wheel
# copying build/lib/whatever4e.py -> build/bdist.macosx-10.5-x86_64/wheel
# running install_egg_info
# running egg_info
# writing dependency_links to whatever4e.egg-info/dependency_links.txt
# writing whatever4e.egg-info/PKG-INFO
# writing requirements to whatever4e.egg-info/requires.txt
# writing top-level names to whatever4e.egg-info/top_level.txt
# reading manifest file 'whatever4e.egg-info/SOURCES.txt'
# reading manifest template 'MANIFEST.in'
# warning: no files found matching '*.ipynb' under directory 'tests/'
# writing manifest file 'whatever4e.egg-info/SOURCES.txt'
# Copying whatever4e.egg-info to build/bdist.macosx-10.5-x86_64/wheel/whatever4e-0.2.0-py3.5.egg-info
# running install_scripts
# creating build/bdist.macosx-10.5-x86_64/wheel/whatever4e-0.2.0.dist-info/WHEEL
# running sdist
# running egg_info
# writing dependency_links to whatever4e.egg-info/dependency_links.txt
# writing top-level names to whatever4e.egg-info/top_level.txt
# writing whatever4e.egg-info/PKG-INFO
# writing requirements to whatever4e.egg-info/requires.txt
# reading manifest file 'whatever4e.egg-info/SOURCES.txt'
# reading manifest template 'MANIFEST.in'
# warning: no files found matching '*.ipynb' under directory 'tests/'
# writing manifest file 'whatever4e.egg-info/SOURCES.txt'
# running check
# creating whatever4e-0.2.0
# creating whatever4e-0.2.0/whatever4e.egg-info
# making hard links in whatever4e-0.2.0...
# hard linking Automation.ipynb -> whatever4e-0.2.0
# hard linking LICENSE -> whatever4e-0.2.0
# hard linking MANIFEST.in -> whatever4e-0.2.0
# hard linking README.ipynb -> whatever4e-0.2.0
# hard linking README.md -> whatever4e-0.2.0
# hard linking README.rst -> whatever4e-0.2.0
# hard linking setup.cfg -> whatever4e-0.2.0
# hard linking setup.py -> whatever4e-0.2.0
# hard linking whatever4e.ipynb -> whatever4e-0.2.0
# hard linking whatever4e.py -> whatever4e-0.2.0
# hard linking whatever4e.egg-info/PKG-INFO -> whatever4e-0.2.0/whatever4e.egg-info
# hard linking whatever4e.egg-info/SOURCES.txt -> whatever4e-0.2.0/whatever4e.egg-info
# hard linking whatever4e.egg-info/dependency_links.txt -> whatever4e-0.2.0/whatever4e.egg-info
# hard linking whatever4e.egg-info/requires.txt -> whatever4e-0.2.0/whatever4e.egg-info
# hard linking whatever4e.egg-info/top_level.txt -> whatever4e-0.2.0/whatever4e.egg-info
# copying setup.cfg -> whatever4e-0.2.0
# Writing whatever4e-0.2.0/setup.cfg
# Creating tar archive
# removing 'whatever4e-0.2.0' (and everything under it)
# running upload
# Submitting dist/whatever4e-0.2.0.tar.gz to https://testpypi.python.org/pypi
# Server response (200): OK
# running bdist_wheel
# running build
# running build_py
# installing to build/bdist.macosx-10.5-x86_64/wheel
# running install
# running install_lib
# creating build/bdist.macosx-10.5-x86_64/wheel
# copying build/lib/whatever4e.py -> build/bdist.macosx-10.5-x86_64/wheel
# running install_egg_info
# running egg_info
# writing top-level names to whatever4e.egg-info/top_level.txt
# writing dependency_links to whatever4e.egg-info/dependency_links.txt
# writing whatever4e.egg-info/PKG-INFO
# writing requirements to whatever4e.egg-info/requires.txt
# reading manifest file 'whatever4e.egg-info/SOURCES.txt'
# reading manifest template 'MANIFEST.in'
# warning: no files found matching '*.ipynb' under directory 'tests/'
# writing manifest file 'whatever4e.egg-info/SOURCES.txt'
# Copying whatever4e.egg-info to build/bdist.macosx-10.5-x86_64/wheel/whatever4e-0.2.0-py3.5.egg-info
# running install_scripts
# creating build/bdist.macosx-10.5-x86_64/wheel/whatever4e-0.2.0.dist-info/WHEEL
# running upload
# Submitting /Users/tfast/w4e/dist/whatever4e-0.2.0-py2.py3-none-any.whl to https://testpypi.python.org/pypi
# Server response (200): OK

# %% [markdown]
# # Cut a real release for PyPi

# %%
# !python setup.py register -r pypi
# !python setup.py sdist
# !python setup.py bdist_wheel
# !python setup.py sdist upload -r pypi
# !python setup.py bdist_wheel upload -r pypi
# Out:
# running register
# running egg_info
# writing top-level names to whatever4e.egg-info/top_level.txt
# writing whatever4e.egg-info/PKG-INFO
# writing dependency_links to whatever4e.egg-info/dependency_links.txt
# writing requirements to whatever4e.egg-info/requires.txt
# reading manifest file 'whatever4e.egg-info/SOURCES.txt'
# reading manifest template 'MANIFEST.in'
# warning: no files found matching '*.ipynb' under directory 'tests/'
# writing manifest file 'whatever4e.egg-info/SOURCES.txt'
# running check
# Registering whatever4e to https://pypi.python.org/pypi
# Server response (200): OK
# running sdist
# running egg_info
# writing requirements to whatever4e.egg-info/requires.txt
# writing dependency_links to whatever4e.egg-info/dependency_links.txt
# writing whatever4e.egg-info/PKG-INFO
# writing top-level names to whatever4e.egg-info/top_level.txt
# reading manifest file 'whatever4e.egg-info/SOURCES.txt'
# reading manifest template 'MANIFEST.in'
# warning: no files found matching '*.ipynb' under directory 'tests/'
# writing manifest file 'whatever4e.egg-info/SOURCES.txt'
# running check
# creating whatever4e-0.2.0
# creating whatever4e-0.2.0/whatever4e.egg-info
# making hard links in whatever4e-0.2.0...
# hard linking Automation.ipynb -> whatever4e-0.2.0
# hard linking LICENSE -> whatever4e-0.2.0
# hard linking MANIFEST.in -> whatever4e-0.2.0
# hard linking README.ipynb -> whatever4e-0.2.0
# hard linking README.md -> whatever4e-0.2.0
# hard linking README.rst -> whatever4e-0.2.0
# hard linking setup.cfg -> whatever4e-0.2.0
# hard linking setup.py -> whatever4e-0.2.0
# hard linking whatever4e.ipynb -> whatever4e-0.2.0
# hard linking whatever4e.py -> whatever4e-0.2.0
# hard linking whatever4e.egg-info/PKG-INFO -> whatever4e-0.2.0/whatever4e.egg-info
# hard linking whatever4e.egg-info/SOURCES.txt -> whatever4e-0.2.0/whatever4e.egg-info
# hard linking whatever4e.egg-info/dependency_links.txt -> whatever4e-0.2.0/whatever4e.egg-info
# hard linking whatever4e.egg-info/requires.txt -> whatever4e-0.2.0/whatever4e.egg-info
# hard linking whatever4e.egg-info/top_level.txt -> whatever4e-0.2.0/whatever4e.egg-info
# copying setup.cfg -> whatever4e-0.2.0
# Writing whatever4e-0.2.0/setup.cfg
# Creating tar archive
# removing 'whatever4e-0.2.0' (and everything under it)
# running bdist_wheel
# running build
# running build_py
# installing to build/bdist.macosx-10.5-x86_64/wheel
# running install
# running install_lib
# creating build/bdist.macosx-10.5-x86_64/wheel
# copying build/lib/whatever4e.py -> build/bdist.macosx-10.5-x86_64/wheel
# running install_egg_info
# running egg_info
# writing whatever4e.egg-info/PKG-INFO
# writing requirements to whatever4e.egg-info/requires.txt
# writing top-level names to whatever4e.egg-info/top_level.txt
# writing dependency_links to whatever4e.egg-info/dependency_links.txt
# reading manifest file 'whatever4e.egg-info/SOURCES.txt'
# reading manifest template 'MANIFEST.in'
# warning: no files found matching '*.ipynb' under directory 'tests/'
# writing manifest file 'whatever4e.egg-info/SOURCES.txt'
# Copying whatever4e.egg-info to build/bdist.macosx-10.5-x86_64/wheel/whatever4e-0.2.0-py3.5.egg-info
# running install_scripts
# creating build/bdist.macosx-10.5-x86_64/wheel/whatever4e-0.2.0.dist-info/WHEEL
# running sdist
# running egg_info
# writing dependency_links to whatever4e.egg-info/dependency_links.txt
# writing top-level names to whatever4e.egg-info/top_level.txt
# writing requirements to whatever4e.egg-info/requires.txt
# writing whatever4e.egg-info/PKG-INFO
# reading manifest file 'whatever4e.egg-info/SOURCES.txt'
# reading manifest template 'MANIFEST.in'
# warning: no files found matching '*.ipynb' under directory 'tests/'
# writing manifest file 'whatever4e.egg-info/SOURCES.txt'
# running check
# creating whatever4e-0.2.0
# creating whatever4e-0.2.0/whatever4e.egg-info
# making hard links in whatever4e-0.2.0...
# hard linking Automation.ipynb -> whatever4e-0.2.0
# hard linking LICENSE -> whatever4e-0.2.0
# hard linking MANIFEST.in -> whatever4e-0.2.0
# hard linking README.ipynb -> whatever4e-0.2.0
# hard linking README.md -> whatever4e-0.2.0
# hard linking README.rst -> whatever4e-0.2.0
# hard linking setup.cfg -> whatever4e-0.2.0
# hard linking setup.py -> whatever4e-0.2.0
# hard linking whatever4e.ipynb -> whatever4e-0.2.0
# hard linking whatever4e.py -> whatever4e-0.2.0
# hard linking whatever4e.egg-info/PKG-INFO -> whatever4e-0.2.0/whatever4e.egg-info
# hard linking whatever4e.egg-info/SOURCES.txt -> whatever4e-0.2.0/whatever4e.egg-info
# hard linking whatever4e.egg-info/dependency_links.txt -> whatever4e-0.2.0/whatever4e.egg-info
# hard linking whatever4e.egg-info/requires.txt -> whatever4e-0.2.0/whatever4e.egg-info
# hard linking whatever4e.egg-info/top_level.txt -> whatever4e-0.2.0/whatever4e.egg-info
# copying setup.cfg -> whatever4e-0.2.0
# Writing whatever4e-0.2.0/setup.cfg
# Creating tar archive
# removing 'whatever4e-0.2.0' (and everything under it)
# running upload
# Submitting dist/whatever4e-0.2.0.tar.gz to https://pypi.python.org/pypi
# Server response (200): OK
# running bdist_wheel
# running build
# running build_py
# installing to build/bdist.macosx-10.5-x86_64/wheel
# running install
# running install_lib
# creating build/bdist.macosx-10.5-x86_64/wheel
# copying build/lib/whatever4e.py -> build/bdist.macosx-10.5-x86_64/wheel
# running install_egg_info
# running egg_info
# writing top-level names to whatever4e.egg-info/top_level.txt
# writing dependency_links to whatever4e.egg-info/dependency_links.txt
# writing whatever4e.egg-info/PKG-INFO
# writing requirements to whatever4e.egg-info/requires.txt
# reading manifest file 'whatever4e.egg-info/SOURCES.txt'
# reading manifest template 'MANIFEST.in'
# warning: no files found matching '*.ipynb' under directory 'tests/'
# writing manifest file 'whatever4e.egg-info/SOURCES.txt'
# Copying whatever4e.egg-info to build/bdist.macosx-10.5-x86_64/wheel/whatever4e-0.2.0-py3.5.egg-info
# running install_scripts
# creating build/bdist.macosx-10.5-x86_64/wheel/whatever4e-0.2.0.dist-info/WHEEL
# running upload
# Submitting /Users/tfast/w4e/dist/whatever4e-0.2.0-py2.py3-none-any.whl to https://pypi.python.org/pypi
# Server response (200): OK
