# %% [markdown]
# ## Automation
# Nothing too fancy here.

# %%
# %%file setup.py
import os
from setuptools import setup


def read(fname):
    """
    Utility function to read the README file.
    Used for the long_description.  It's nice, because now 1) we have a top
    level README file and 2) it's easier to type in the README file than to put
    a raw string in below ...
    """
    with open(os.path.join(os.path.dirname(__file__), fname)) as f:
        return f.read()


setup(
    name="whatever-forever",
    version="0.0.7",
    author="Tony Fast",
    author_email="tony.fast@gmail.com",
    description="prototype whatever in the Jupyter notebook",
    license="BSD",
    keywords="IPython Magic Jupyter",
    url="http://github.com/tonyfast/whatever-forever",
    py_modules=["whatever-forever"],
    long_description=read("README.rst"),
    classifiers=[
        "Topic :: Utilities",
        "Framework :: IPython",
        "Natural Language :: English",
        "Programming Language :: Python",
        "Intended Audience :: Developers",
        "Development Status :: 3 - Alpha",
        "Operating System :: OS Independent",
        "Programming Language :: Python :: 3",
        "License :: OSI Approved :: BSD License",
        "Topic :: Software Development :: Testing",
    ],
    install_requires=[
        "toolz",
    ]
)
# Out:
# Overwriting setup.py

# %%
# !jupyter nbconvert --to python source/__init__.ipynb
# !jupyter nbconvert --to python source/chain.ipynb
# !jupyter nbconvert --to python source/magic.ipynb
# !cp source/__init__.py whatever4e/__init__.py
# !cp source/magic.py whatever4e/magic.py
# !cp source/chain.py whatever4e/chain.py
# !cp source/class_maker.py whatever4e/class_maker.py

# !jupyter nbconvert --to rst source/__init__.ipynb
# !cp source/__init__.rst README.rst

from glob import glob

for the_script in glob('whatever4e/*.py'):
    with open(the_script,'r') as f:
        src = f.read()
    with open(the_script,'w') as f:
        f.write(src.replace(
                'from class_maker import',
                'from .class_maker import'
            ))
# Out:
# [NbConvertApp] Converting notebook source/__init__.ipynb to python
# [NbConvertApp] Writing 1427 bytes to source/__init__.py
# [NbConvertApp] Converting notebook source/chain.ipynb to python
# [NbConvertApp] Writing 7287 bytes to source/chain.py
# [NbConvertApp] Converting notebook source/magic.ipynb to python
# [NbConvertApp] Writing 2900 bytes to source/magic.py
# [NbConvertApp] Converting notebook source/__init__.ipynb to rst
# [NbConvertApp] Writing 1498 bytes to source/__init__.rst

# %% [markdown]
# ### Run tests

# %%
# !python setup.py test

# %% [markdown]
# ### Check code style

# %%
# !flake8

# %% [markdown]
# ## Test Release for PyPi

# %%
# !python setup.py register -r pypitest
# !python setup.py sdist
# !python setup.py bdist_wheel
# !python setup.py sdist upload -r pypitest
# !python setup.py bdist_wheel upload -r pypitest
# Out:
# running register
# running egg_info
# writing whatever_forever.egg-info/PKG-INFO
# writing requirements to whatever_forever.egg-info/requires.txt
# writing dependency_links to whatever_forever.egg-info/dependency_links.txt
# writing top-level names to whatever_forever.egg-info/top_level.txt
# file whatever-forever.py (for module whatever-forever) not found
# reading manifest file 'whatever_forever.egg-info/SOURCES.txt'
# reading manifest template 'MANIFEST.in'
# warning: no files found matching '*.md'
# warning: no files found matching '*.ipynb' under directory 'tests/'
# writing manifest file 'whatever_forever.egg-info/SOURCES.txt'
# Traceback (most recent call last):
#   File "setup.py", line 40, in <module>
#     "toolz",
#   File "/Users/fresh/anaconda/lib/python3.5/distutils/core.py", line 148, in setup
#     dist.run_commands()
#   File "/Users/fresh/anaconda/lib/python3.5/distutils/dist.py", line 955, in run_commands
#     self.run_command(cmd)
#   File "/Users/fresh/anaconda/lib/python3.5/distutils/dist.py", line 974, in run_command
#     cmd_obj.run()
#   File "/Users/fresh/anaconda/lib/python3.5/site-packages/setuptools-23.0.0-py3.5.egg/setuptools/command/register.py", line 10, in run
#   File "/Users/fresh/anaconda/lib/python3.5/distutils/command/register.py", line 45, in run
#     self._set_config()
#   File "/Users/fresh/anaconda/lib/python3.5/distutils/command/register.py", line 80, in _set_config
#     raise ValueError('%s not found in .pypirc' % self.repository)
# ValueError: pypitest not found in .pypirc
# running sdist
# running egg_info
# writing whatever_forever.egg-info/PKG-INFO
# writing dependency_links to whatever_forever.egg-info/dependency_links.txt
# writing top-level names to whatever_forever.egg-info/top_level.txt
# writing requirements to whatever_forever.egg-info/requires.txt
# file whatever-forever.py (for module whatever-forever) not found
# reading manifest file 'whatever_forever.egg-info/SOURCES.txt'
# reading manifest template 'MANIFEST.in'
# warning: no files found matching '*.md'
# warning: no files found matching '*.ipynb' under directory 'tests/'
# writing manifest file 'whatever_forever.egg-info/SOURCES.txt'
# running check
# creating whatever-forever-0.0.7
# creating whatever-forever-0.0.7/whatever_forever.egg-info
# making hard links in whatever-forever-0.0.7...
# hard linking Automation.ipynb -> whatever-forever-0.0.7
# hard linking LICENSE -> whatever-forever-0.0.7
# hard linking MANIFEST.in -> whatever-forever-0.0.7
# hard linking Principal Component Viewer.ipynb -> whatever-forever-0.0.7
# hard linking README.rst -> whatever-forever-0.0.7
# hard linking Untitled.ipynb -> whatever-forever-0.0.7
# hard linking Untitled1.ipynb -> whatever-forever-0.0.7
# hard linking Untitled196.ipynb -> whatever-forever-0.0.7
# hard linking Untitled2.ipynb -> whatever-forever-0.0.7
# hard linking aasdf.ipynb -> whatever-forever-0.0.7
# hard linking meetuper.ipynb -> whatever-forever-0.0.7
# hard linking setup.cfg -> whatever-forever-0.0.7
# hard linking setup.py -> whatever-forever-0.0.7
# hard linking whatever_forever.egg-info/PKG-INFO -> whatever-forever-0.0.7/whatever_forever.egg-info
# hard linking whatever_forever.egg-info/SOURCES.txt -> whatever-forever-0.0.7/whatever_forever.egg-info
# hard linking whatever_forever.egg-info/dependency_links.txt -> whatever-forever-0.0.7/whatever_forever.egg-info
# hard linking whatever_forever.egg-info/requires.txt -> whatever-forever-0.0.7/whatever_forever.egg-info
# hard linking whatever_forever.egg-info/top_level.txt -> whatever-forever-0.0.7/whatever_forever.egg-info
# copying setup.cfg -> whatever-forever-0.0.7
# Writing whatever-forever-0.0.7/setup.cfg
# Creating tar archive
# removing 'whatever-forever-0.0.7' (and everything under it)
# running bdist_wheel
# running build
# running build_py
# file whatever-forever.py (for module whatever-forever) not found
# file whatever-forever.py (for module whatever-forever) not found
# installing to build/bdist.macosx-10.6-x86_64/wheel
# running install
# running install_lib
# warning: install_lib: 'build/lib' does not exist -- no Python modules to install
#
# running install_egg_info
# running egg_info
# writing requirements to whatever_forever.egg-info/requires.txt
# writing dependency_links to whatever_forever.egg-info/dependency_links.txt
# writing whatever_forever.egg-info/PKG-INFO
# writing top-level names to whatever_forever.egg-info/top_level.txt
# file whatever-forever.py (for module whatever-forever) not found
# reading manifest file 'whatever_forever.egg-info/SOURCES.txt'
# reading manifest template 'MANIFEST.in'
# warning: no files found matching '*.md'
# warning: no files found matching '*.ipynb' under directory 'tests/'
# writing manifest file 'whatever_forever.egg-info/SOURCES.txt'
# Copying whatever_forever.egg-info to build/bdist.macosx-10.6-x86_64/wheel/whatever_forever-0.0.7-py3.5.egg-info
# running install_scripts
# creating build/bdist.macosx-10.6-x86_64/wheel/whatever_forever-0.0.7.dist-info/WHEEL
# running sdist
# running egg_info
# writing top-level names to whatever_forever.egg-info/top_level.txt
# writing whatever_forever.egg-info/PKG-INFO
# writing dependency_links to whatever_forever.egg-info/dependency_links.txt
# writing requirements to whatever_forever.egg-info/requires.txt
# file whatever-forever.py (for module whatever-forever) not found
# reading manifest file 'whatever_forever.egg-info/SOURCES.txt'
# reading manifest template 'MANIFEST.in'
# warning: no files found matching '*.md'
# warning: no files found matching '*.ipynb' under directory 'tests/'
# writing manifest file 'whatever_forever.egg-info/SOURCES.txt'
# running check
# creating whatever-forever-0.0.7
# creating whatever-forever-0.0.7/whatever_forever.egg-info
# making hard links in whatever-forever-0.0.7...
# hard linking Automation.ipynb -> whatever-forever-0.0.7
# hard linking LICENSE -> whatever-forever-0.0.7
# hard linking MANIFEST.in -> whatever-forever-0.0.7
# hard linking Principal Component Viewer.ipynb -> whatever-forever-0.0.7
# hard linking README.rst -> whatever-forever-0.0.7
# hard linking Untitled.ipynb -> whatever-forever-0.0.7
# hard linking Untitled1.ipynb -> whatever-forever-0.0.7
# hard linking Untitled196.ipynb -> whatever-forever-0.0.7
# hard linking Untitled2.ipynb -> whatever-forever-0.0.7
# hard linking aasdf.ipynb -> whatever-forever-0.0.7
# hard linking meetuper.ipynb -> whatever-forever-0.0.7
# hard linking setup.cfg -> whatever-forever-0.0.7
# hard linking setup.py -> whatever-forever-0.0.7
# hard linking whatever_forever.egg-info/PKG-INFO -> whatever-forever-0.0.7/whatever_forever.egg-info
# hard linking whatever_forever.egg-info/SOURCES.txt -> whatever-forever-0.0.7/whatever_forever.egg-info
# hard linking whatever_forever.egg-info/dependency_links.txt -> whatever-forever-0.0.7/whatever_forever.egg-info
# hard linking whatever_forever.egg-info/requires.txt -> whatever-forever-0.0.7/whatever_forever.egg-info
# hard linking whatever_forever.egg-info/top_level.txt -> whatever-forever-0.0.7/whatever_forever.egg-info
# copying setup.cfg -> whatever-forever-0.0.7
# Writing whatever-forever-0.0.7/setup.cfg
# Creating tar archive
# removing 'whatever-forever-0.0.7' (and everything under it)
# running upload
# Password: Traceback (most recent call last):
#   File "setup.py", line 40, in <module>
#     "toolz",
#   File "/Users/fresh/anaconda/lib/python3.5/distutils/core.py", line 148, in setup
#     dist.run_commands()
#   File "/Users/fresh/anaconda/lib/python3.5/distutils/dist.py", line 955, in run_commands
#     self.run_command(cmd)
#   File "/Users/fresh/anaconda/lib/python3.5/distutils/dist.py", line 974, in run_command
#     cmd_obj.run()
#   File "/Users/fresh/anaconda/lib/python3.5/distutils/command/upload.py", line 63, in run
#     self.upload_file(command, pyversion, filename)
#   File "/Users/fresh/anaconda/lib/python3.5/distutils/command/upload.py", line 73, in upload_file
#     raise AssertionError("unsupported schema " + schema)
# AssertionError: unsupported schema
#
# running bdist_wheel
# running build
# running build_py
# file whatever-forever.py (for module whatever-forever) not found
# file whatever-forever.py (for module whatever-forever) not found
# installing to build/bdist.macosx-10.6-x86_64/wheel
# running install
# running install_lib
# warning: install_lib: 'build/lib' does not exist -- no Python modules to install
#
# running install_egg_info
# running egg_info
# writing whatever_forever.egg-info/PKG-INFO
# writing top-level names to whatever_forever.egg-info/top_level.txt
# writing dependency_links to whatever_forever.egg-info/dependency_links.txt
# writing requirements to whatever_forever.egg-info/requires.txt
# file whatever-forever.py (for module whatever-forever) not found
# reading manifest file 'whatever_forever.egg-info/SOURCES.txt'
# reading manifest template 'MANIFEST.in'
# warning: no files found matching '*.md'
# warning: no files found matching '*.ipynb' under directory 'tests/'
# writing manifest file 'whatever_forever.egg-info/SOURCES.txt'
# Copying whatever_forever.egg-info to build/bdist.macosx-10.6-x86_64/wheel/whatever_forever-0.0.7-py3.5.egg-info
# running install_scripts
# creating build/bdist.macosx-10.6-x86_64/wheel/whatever_forever-0.0.7.dist-info/WHEEL
# running upload
# Password:

# %% [markdown]
# # Cut a real release for PyPi

# %%
# !python setup.py register -r pypi
# !python setup.py sdist
# !python setup.py bdist_wheel
# !python setup.py sdist upload -r pypi
# !python setup.py bdist_wheel upload -r pypi
# Out:
# running register
# running egg_info
# writing top-level names to whatever_forever.egg-info/top_level.txt
# writing dependency_links to whatever_forever.egg-info/dependency_links.txt
# writing requirements to whatever_forever.egg-info/requires.txt
# writing whatever_forever.egg-info/PKG-INFO
# file whatever-forever.py (for module whatever-forever) not found
# reading manifest file 'whatever_forever.egg-info/SOURCES.txt'
# reading manifest template 'MANIFEST.in'
# warning: no files found matching '*.md'
# warning: no files found matching '*.ipynb' under directory 'tests/'
# writing manifest file 'whatever_forever.egg-info/SOURCES.txt'
# running check
# Registering whatever-forever to https://pypi.python.org/pypi
# Server response (200): OK
# running sdist
# running egg_info
# writing dependency_links to whatever_forever.egg-info/dependency_links.txt
# writing whatever_forever.egg-info/PKG-INFO
# writing requirements to whatever_forever.egg-info/requires.txt
# writing top-level names to whatever_forever.egg-info/top_level.txt
# file whatever-forever.py (for module whatever-forever) not found
# reading manifest file 'whatever_forever.egg-info/SOURCES.txt'
# reading manifest template 'MANIFEST.in'
# warning: no files found matching '*.md'
# warning: no files found matching '*.ipynb' under directory 'tests/'
# writing manifest file 'whatever_forever.egg-info/SOURCES.txt'
# running check
# creating whatever-forever-0.0.7
# creating whatever-forever-0.0.7/whatever_forever.egg-info
# making hard links in whatever-forever-0.0.7...
# hard linking Automation.ipynb -> whatever-forever-0.0.7
# hard linking LICENSE -> whatever-forever-0.0.7
# hard linking MANIFEST.in -> whatever-forever-0.0.7
# hard linking Principal Component Viewer.ipynb -> whatever-forever-0.0.7
# hard linking README.rst -> whatever-forever-0.0.7
# hard linking Untitled.ipynb -> whatever-forever-0.0.7
# hard linking Untitled1.ipynb -> whatever-forever-0.0.7
# hard linking Untitled196.ipynb -> whatever-forever-0.0.7
# hard linking Untitled2.ipynb -> whatever-forever-0.0.7
# hard linking aasdf.ipynb -> whatever-forever-0.0.7
# hard linking meetuper.ipynb -> whatever-forever-0.0.7
# hard linking setup.cfg -> whatever-forever-0.0.7
# hard linking setup.py -> whatever-forever-0.0.7
# hard linking whatever_forever.egg-info/PKG-INFO -> whatever-forever-0.0.7/whatever_forever.egg-info
# hard linking whatever_forever.egg-info/SOURCES.txt -> whatever-forever-0.0.7/whatever_forever.egg-info
# hard linking whatever_forever.egg-info/dependency_links.txt -> whatever-forever-0.0.7/whatever_forever.egg-info
# hard linking whatever_forever.egg-info/requires.txt -> whatever-forever-0.0.7/whatever_forever.egg-info
# hard linking whatever_forever.egg-info/top_level.txt -> whatever-forever-0.0.7/whatever_forever.egg-info
# copying setup.cfg -> whatever-forever-0.0.7
# Writing whatever-forever-0.0.7/setup.cfg
# Creating tar archive
# removing 'whatever-forever-0.0.7' (and everything under it)
# running bdist_wheel
# running build
# running build_py
# file whatever-forever.py (for module whatever-forever) not found
# file whatever-forever.py (for module whatever-forever) not found
# installing to build/bdist.macosx-10.6-x86_64/wheel
# running install
# running install_lib
# warning: install_lib: 'build/lib' does not exist -- no Python modules to install
#
# running install_egg_info
# running egg_info
# writing top-level names to whatever_forever.egg-info/top_level.txt
# writing requirements to whatever_forever.egg-info/requires.txt
# writing dependency_links to whatever_forever.egg-info/dependency_links.txt
# writing whatever_forever.egg-info/PKG-INFO
# file whatever-forever.py (for module whatever-forever) not found
# reading manifest file 'whatever_forever.egg-info/SOURCES.txt'
# reading manifest template 'MANIFEST.in'
# warning: no files found matching '*.md'
# warning: no files found matching '*.ipynb' under directory 'tests/'
# writing manifest file 'whatever_forever.egg-info/SOURCES.txt'
# Copying whatever_forever.egg-info to build/bdist.macosx-10.6-x86_64/wheel/whatever_forever-0.0.7-py3.5.egg-info
# running install_scripts
# creating build/bdist.macosx-10.6-x86_64/wheel/whatever_forever-0.0.7.dist-info/WHEEL
# running sdist
# running egg_info
# writing top-level names to whatever_forever.egg-info/top_level.txt
# writing whatever_forever.egg-info/PKG-INFO
# writing requirements to whatever_forever.egg-info/requires.txt
# writing dependency_links to whatever_forever.egg-info/dependency_links.txt
# file whatever-forever.py (for module whatever-forever) not found
# reading manifest file 'whatever_forever.egg-info/SOURCES.txt'
# reading manifest template 'MANIFEST.in'
# warning: no files found matching '*.md'
# warning: no files found matching '*.ipynb' under directory 'tests/'
# writing manifest file 'whatever_forever.egg-info/SOURCES.txt'
# running check
# creating whatever-forever-0.0.7
# creating whatever-forever-0.0.7/whatever_forever.egg-info
# making hard links in whatever-forever-0.0.7...
# hard linking Automation.ipynb -> whatever-forever-0.0.7
# hard linking LICENSE -> whatever-forever-0.0.7
# hard linking MANIFEST.in -> whatever-forever-0.0.7
# hard linking Principal Component Viewer.ipynb -> whatever-forever-0.0.7
# hard linking README.rst -> whatever-forever-0.0.7
# hard linking Untitled.ipynb -> whatever-forever-0.0.7
# hard linking Untitled1.ipynb -> whatever-forever-0.0.7
# hard linking Untitled196.ipynb -> whatever-forever-0.0.7
# hard linking Untitled2.ipynb -> whatever-forever-0.0.7
# hard linking aasdf.ipynb -> whatever-forever-0.0.7
# hard linking meetuper.ipynb -> whatever-forever-0.0.7
# hard linking setup.cfg -> whatever-forever-0.0.7
# hard linking setup.py -> whatever-forever-0.0.7
# hard linking whatever_forever.egg-info/PKG-INFO -> whatever-forever-0.0.7/whatever_forever.egg-info
# hard linking whatever_forever.egg-info/SOURCES.txt -> whatever-forever-0.0.7/whatever_forever.egg-info
# hard linking whatever_forever.egg-info/dependency_links.txt -> whatever-forever-0.0.7/whatever_forever.egg-info
# hard linking whatever_forever.egg-info/requires.txt -> whatever-forever-0.0.7/whatever_forever.egg-info
# hard linking whatever_forever.egg-info/top_level.txt -> whatever-forever-0.0.7/whatever_forever.egg-info
# copying setup.cfg -> whatever-forever-0.0.7
# Writing whatever-forever-0.0.7/setup.cfg
# Creating tar archive
# removing 'whatever-forever-0.0.7' (and everything under it)
# running upload
# Submitting dist/whatever-forever-0.0.7.tar.gz to https://pypi.python.org/pypi
# Server response (200): OK
# running bdist_wheel
# running build
# running build_py
# file whatever-forever.py (for module whatever-forever) not found
# file whatever-forever.py (for module whatever-forever) not found
# installing to build/bdist.macosx-10.6-x86_64/wheel
# running install
# running install_lib
# warning: install_lib: 'build/lib' does not exist -- no Python modules to install
#
# running install_egg_info
# running egg_info
# writing whatever_forever.egg-info/PKG-INFO
# writing top-level names to whatever_forever.egg-info/top_level.txt
# writing dependency_links to whatever_forever.egg-info/dependency_links.txt
# writing requirements to whatever_forever.egg-info/requires.txt
# file whatever-forever.py (for module whatever-forever) not found
# reading manifest file 'whatever_forever.egg-info/SOURCES.txt'
# reading manifest template 'MANIFEST.in'
# warning: no files found matching '*.md'
# warning: no files found matching '*.ipynb' under directory 'tests/'
# writing manifest file 'whatever_forever.egg-info/SOURCES.txt'
# Copying whatever_forever.egg-info to build/bdist.macosx-10.6-x86_64/wheel/whatever_forever-0.0.7-py3.5.egg-info
# running install_scripts
# creating build/bdist.macosx-10.6-x86_64/wheel/whatever_forever-0.0.7.dist-info/WHEEL
# running upload
# Submitting /Users/fresh/w4e/dist/whatever_forever-0.0.7-py2.py3-none-any.whl to https://pypi.python.org/pypi
# Server response (200): OK

# %%
# !pip install whatever-forever==0.0.6 --upgrade
# Out:
# Requirement already up-to-date: whatever-forever==0.0.6 in /Users/fresh/anaconda/lib/python3.5/site-packages
# Requirement already up-to-date: toolz in /Users/fresh/anaconda/lib/python3.5/site-packages (from whatever-forever==0.0.6)
