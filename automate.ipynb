# %% [markdown]
# ## Automation
# Nothing too fancy here.

# %%
# %%file tricks.yaml
# tricks:
# - watchdog.tricks.ShellCommandTrick:
#     patterns: 
#     - "*.ipynb"
#     ignore_patterns: ['*/.~*.ipynb', '*/.ipynb_checkpoints*']
#     shell_command: >
#         jupyter nbconvert --to script "${watch_src_path}" && python automate.py && py.test
# Out:
# Overwriting tricks.yaml

# %%
# %%file setup.py
# from os.path import join, dirname
# import setuptools

# def read(fname):
#     with open(join(dirname(__file__), fname)) as f:
#         return f.read()

# setuptools.setup(
#     name="whatever-forever",
#     version="0.0.11",
#     author="Tony Fast",
#     author_email="tony.fast@gmail.com",
#     description="prototype whatever in the Jupyter notebook",
#     license="BSD-3-Clause",
#     keywords="IPython Magic Jupyter",
#     url="http://github.com/tonyfast/whatever-forever",
#     packages=setuptools.find_packages(),
#     long_description=read("README.rst"),
#     classifiers=[
#         "Topic :: Utilities",
#         "Framework :: IPython",
#         "Natural Language :: English",
#         "Programming Language :: Python",
#         "Intended Audience :: Developers",
#         "Development Status :: 3 - Alpha",
#         "Operating System :: OS Independent",
#         "Programming Language :: Python :: 3",
#         "License :: OSI Approved :: BSD License",
#         "Topic :: Software Development :: Testing",
#     ],
#     install_requires=[
#         "toolz",
#     ]
# )
# Out:
# Overwriting setup.py

# %%
# %load automate.py


# ## Automation
# Nothing too fancy here.

# In[26]:

# %%file tricks.yaml
# tricks:
# - watchdog.tricks.ShellCommandTrick:
#     patterns: 
#     - "*.ipynb"
#     ignore_patterns: ['*/.~*.ipynb', '*/.ipynb_checkpoints*']
#     shell_command: >
#         jupyter nbconvert --to script "${watch_src_path}" && &&py.test


# In[75]:

# %%file setup.py
# from os.path import join, dirname
# import setuptools

# def read(fname):
#     with open(join(dirname(__file__), fname)) as f:
#         return f.read()

# setuptools.setup(
#     name="whatever-forever",
#     version="0.0.11",
#     author="Tony Fast",
#     author_email="tony.fast@gmail.com",
#     description="prototype whatever in the Jupyter notebook",
#     license="BSD-3-Clause",
#     keywords="IPython Magic Jupyter",
#     url="http://github.com/tonyfast/whatever-forever",
#     packages=setuptools.find_packages(),
#     long_description=read("README.rst"),
#     classifiers=[
#         "Topic :: Utilities",
#         "Framework :: IPython",
#         "Natural Language :: English",
#         "Programming Language :: Python",
#         "Intended Audience :: Developers",
#         "Development Status :: 3 - Alpha",
#         "Operating System :: OS Independent",
#         "Programming Language :: Python :: 3",
#         "License :: OSI Approved :: BSD License",
#         "Topic :: Software Development :: Testing",
#     ],
#     install_requires=[
#         "toolz",
#     ]
# )


# In[7]:

# %%
import os
from glob import glob
from pyquery import PyQuery as pq
from nbconvert import export_html
for the_script in glob('whatever/*.py'):
    with open(the_script) as f:
        src = f.read()
    with open(the_script, 'w') as f:
        f.write(src.replace('from class_maker import', 'from .class_maker import'))

for the_docs in [*glob('docs/*.ipynb'), *glob('docs/**/*.ipynb')]:
    with open(the_docs) as f:
        q = pq(export_html(the_docs)[0])
    path = the_docs.split('/')
    fn = path[-1]
    directory = '/'.join(path[:-1])
    if not os.path.isdir(directory):
        makedirs(directory)
    with open(directory+'/'+fn.replace('.ipynb','.html'), 'w') as f:
        f.write(
            """---
layout: index
---
{% raw %}"""+q('body').html()+ """
{% endraw %}""")
directory = 'docs/_layouts'
if not os.path.isdir(directory):
    makedirs(directory)

with open('docs/_layouts/index.html', 'w') as f:
    q('body').html('{{content}}',method='html')
    f.write(
        """<!doctype html><html>"""+q.html(method='html').strip()+"""</html>"""
    )

# %%
# In[8]:

# !python setup.py develop


# ### Run tests

# In[25]:

# !flake8


# ## Test Release for PyPi

# In[26]:

# !python setup.py register -r pypitest
# !python setup.py sdist
# !python setup.py bdist_wheel
# !python setup.py sdist upload -r pypitest
# !python setup.py bdist_wheel upload -r pypitest


# # Cut a real release for PyPi

# In[28]:

# !python setup.py register -r pypi
# !python setup.py sdist
# !python setup.py bdist_wheel
# !python setup.py sdist upload -r pypi
# !python setup.py bdist_wheel upload -r pypi


# In[30]:

# !pip install whatever-forever --upgrade --no-cache-dir


# In[ ]:

# %%
from glob import glob
for the_script in glob('whatever/*.py'):
    with open(the_script) as f:
        src = f.read()
    with open(the_script, 'w') as f:
        f.write(src.replace('from class_maker import', 'from .class_maker import'))

# %%
# !python setup.py develop
# Out:
# running develop
# running egg_info
# writing top-level names to whatever_forever.egg-info/top_level.txt
# writing dependency_links to whatever_forever.egg-info/dependency_links.txt
# writing requirements to whatever_forever.egg-info/requires.txt
# writing whatever_forever.egg-info/PKG-INFO
# reading manifest file 'whatever_forever.egg-info/SOURCES.txt'
# reading manifest template 'MANIFEST.in'
# warning: no files found matching '*.md'
# warning: no files found matching '*.ipynb' under directory 'tests/'
# writing manifest file 'whatever_forever.egg-info/SOURCES.txt'
# running build_ext
# Creating /Users/tfast/anaconda/lib/python3.5/site-packages/whatever-forever.egg-link (link to .)
# whatever-forever 0.0.11 is already the active version in easy-install.pth
#
# Installed /Users/tfast/whatever-forever
# Processing dependencies for whatever-forever==0.0.11
# Searching for toolz==0.8.0
# Best match: toolz 0.8.0
# Adding toolz 0.8.0 to easy-install.pth file
#
# Using /Users/tfast/anaconda/lib/python3.5/site-packages
# Finished processing dependencies for whatever-forever==0.0.11

# %% [markdown]
# ### Run tests

# %%
# !flake8

# %% [markdown]
# ## Test Release for PyPi

# %%
# !python setup.py register -r pypitest
# !python setup.py sdist
# !python setup.py bdist_wheel
# !python setup.py sdist upload -r pypitest
# !python setup.py bdist_wheel upload -r pypitest
# Out:
# running register
# running egg_info
# writing requirements to whatever_forever.egg-info/requires.txt
# writing whatever_forever.egg-info/PKG-INFO
# writing top-level names to whatever_forever.egg-info/top_level.txt
# writing dependency_links to whatever_forever.egg-info/dependency_links.txt
# reading manifest file 'whatever_forever.egg-info/SOURCES.txt'
# reading manifest template 'MANIFEST.in'
# warning: no files found matching '*.md'
# warning: no files found matching '*.ipynb' under directory 'tests/'
# writing manifest file 'whatever_forever.egg-info/SOURCES.txt'
# running check
# Registering whatever-forever to https://testpypi.python.org/pypi
# ^Cinterrupted
#
# running sdist
# running egg_info
# writing whatever_forever.egg-info/PKG-INFO
# writing requirements to whatever_forever.egg-info/requires.txt
# writing dependency_links to whatever_forever.egg-info/dependency_links.txt
# writing top-level names to whatever_forever.egg-info/top_level.txt
# reading manifest file 'whatever_forever.egg-info/SOURCES.txt'
# reading manifest template 'MANIFEST.in'
# warning: no files found matching '*.md'
# warning: no files found matching '*.ipynb' under directory 'tests/'
# writing manifest file 'whatever_forever.egg-info/SOURCES.txt'
# running check
# creating whatever-forever-0.0.11
# creating whatever-forever-0.0.11/whatever
# creating whatever-forever-0.0.11/whatever4e
# creating whatever-forever-0.0.11/whatever_forever.egg-info
# making hard links in whatever-forever-0.0.11...
# hard linking Automation.ipynb -> whatever-forever-0.0.11
# hard linking LICENSE -> whatever-forever-0.0.11
# hard linking MANIFEST.in -> whatever-forever-0.0.11
# hard linking README.rst -> whatever-forever-0.0.11
# hard linking Untitled1.ipynb -> whatever-forever-0.0.11
# hard linking setup.cfg -> whatever-forever-0.0.11
# hard linking setup.py -> whatever-forever-0.0.11
# hard linking whatever/Untitled.py -> whatever-forever-0.0.11/whatever
# hard linking whatever/Untitled1.py -> whatever-forever-0.0.11/whatever
# hard linking whatever/__init__.py -> whatever-forever-0.0.11/whatever
# hard linking whatever/chain.py -> whatever-forever-0.0.11/whatever
# hard linking whatever/class_maker.py -> whatever-forever-0.0.11/whatever
# hard linking whatever/imports_for_whatever_forever.py -> whatever-forever-0.0.11/whatever
# hard linking whatever/magic.py -> whatever-forever-0.0.11/whatever
# hard linking whatever/polymorphisms.py -> whatever-forever-0.0.11/whatever
# hard linking whatever4e/__init__.py -> whatever-forever-0.0.11/whatever4e
# hard linking whatever4e/chain.py -> whatever-forever-0.0.11/whatever4e
# hard linking whatever4e/class_maker.py -> whatever-forever-0.0.11/whatever4e
# hard linking whatever4e/magic.py -> whatever-forever-0.0.11/whatever4e
# hard linking whatever_forever.egg-info/PKG-INFO -> whatever-forever-0.0.11/whatever_forever.egg-info
# hard linking whatever_forever.egg-info/SOURCES.txt -> whatever-forever-0.0.11/whatever_forever.egg-info
# hard linking whatever_forever.egg-info/dependency_links.txt -> whatever-forever-0.0.11/whatever_forever.egg-info
# hard linking whatever_forever.egg-info/requires.txt -> whatever-forever-0.0.11/whatever_forever.egg-info
# hard linking whatever_forever.egg-info/top_level.txt -> whatever-forever-0.0.11/whatever_forever.egg-info
# copying setup.cfg -> whatever-forever-0.0.11
# Writing whatever-forever-0.0.11/setup.cfg
# Creating tar archive
# removing 'whatever-forever-0.0.11' (and everything under it)
# running bdist_wheel
# running build
# running build_py
# creating build/lib/whatever
# copying whatever/__init__.py -> build/lib/whatever
# copying whatever/chain.py -> build/lib/whatever
# copying whatever/class_maker.py -> build/lib/whatever
# copying whatever/imports_for_whatever_forever.py -> build/lib/whatever
# copying whatever/magic.py -> build/lib/whatever
# copying whatever/polymorphisms.py -> build/lib/whatever
# copying whatever/Untitled.py -> build/lib/whatever
# copying whatever/Untitled1.py -> build/lib/whatever
# installing to build/bdist.macosx-10.6-x86_64/wheel
# running install
# running install_lib
# creating build/bdist.macosx-10.6-x86_64/wheel
# creating build/bdist.macosx-10.6-x86_64/wheel/whatever
# copying build/lib/whatever/__init__.py -> build/bdist.macosx-10.6-x86_64/wheel/whatever
# copying build/lib/whatever/chain.py -> build/bdist.macosx-10.6-x86_64/wheel/whatever
# copying build/lib/whatever/class_maker.py -> build/bdist.macosx-10.6-x86_64/wheel/whatever
# copying build/lib/whatever/imports_for_whatever_forever.py -> build/bdist.macosx-10.6-x86_64/wheel/whatever
# copying build/lib/whatever/magic.py -> build/bdist.macosx-10.6-x86_64/wheel/whatever
# copying build/lib/whatever/polymorphisms.py -> build/bdist.macosx-10.6-x86_64/wheel/whatever
# copying build/lib/whatever/Untitled.py -> build/bdist.macosx-10.6-x86_64/wheel/whatever
# copying build/lib/whatever/Untitled1.py -> build/bdist.macosx-10.6-x86_64/wheel/whatever
# creating build/bdist.macosx-10.6-x86_64/wheel/whatever4e
# copying build/lib/whatever4e/__init__.py -> build/bdist.macosx-10.6-x86_64/wheel/whatever4e
# copying build/lib/whatever4e/chain.py -> build/bdist.macosx-10.6-x86_64/wheel/whatever4e
# copying build/lib/whatever4e/class_maker.py -> build/bdist.macosx-10.6-x86_64/wheel/whatever4e
# copying build/lib/whatever4e/magic.py -> build/bdist.macosx-10.6-x86_64/wheel/whatever4e
# running install_egg_info
# running egg_info
# writing requirements to whatever_forever.egg-info/requires.txt
# writing whatever_forever.egg-info/PKG-INFO
# writing dependency_links to whatever_forever.egg-info/dependency_links.txt
# writing top-level names to whatever_forever.egg-info/top_level.txt
# reading manifest file 'whatever_forever.egg-info/SOURCES.txt'
# reading manifest template 'MANIFEST.in'
# warning: no files found matching '*.md'
# warning: no files found matching '*.ipynb' under directory 'tests/'
# writing manifest file 'whatever_forever.egg-info/SOURCES.txt'
# Copying whatever_forever.egg-info to build/bdist.macosx-10.6-x86_64/wheel/whatever_forever-0.0.11-py3.5.egg-info
# running install_scripts
# creating build/bdist.macosx-10.6-x86_64/wheel/whatever_forever-0.0.11.dist-info/WHEEL
# running sdist
# running egg_info
# writing whatever_forever.egg-info/PKG-INFO
# writing requirements to whatever_forever.egg-info/requires.txt
# writing top-level names to whatever_forever.egg-info/top_level.txt
# writing dependency_links to whatever_forever.egg-info/dependency_links.txt
# reading manifest file 'whatever_forever.egg-info/SOURCES.txt'
# reading manifest template 'MANIFEST.in'
# warning: no files found matching '*.md'
# warning: no files found matching '*.ipynb' under directory 'tests/'
# writing manifest file 'whatever_forever.egg-info/SOURCES.txt'
# running check
# creating whatever-forever-0.0.11
# creating whatever-forever-0.0.11/whatever
# creating whatever-forever-0.0.11/whatever4e
# creating whatever-forever-0.0.11/whatever_forever.egg-info
# making hard links in whatever-forever-0.0.11...
# hard linking Automation.ipynb -> whatever-forever-0.0.11
# hard linking LICENSE -> whatever-forever-0.0.11
# hard linking MANIFEST.in -> whatever-forever-0.0.11
# hard linking README.rst -> whatever-forever-0.0.11
# hard linking Untitled1.ipynb -> whatever-forever-0.0.11
# hard linking setup.cfg -> whatever-forever-0.0.11
# hard linking setup.py -> whatever-forever-0.0.11
# hard linking whatever/Untitled.py -> whatever-forever-0.0.11/whatever
# hard linking whatever/Untitled1.py -> whatever-forever-0.0.11/whatever
# hard linking whatever/__init__.py -> whatever-forever-0.0.11/whatever
# hard linking whatever/chain.py -> whatever-forever-0.0.11/whatever
# hard linking whatever/class_maker.py -> whatever-forever-0.0.11/whatever
# hard linking whatever/imports_for_whatever_forever.py -> whatever-forever-0.0.11/whatever
# hard linking whatever/magic.py -> whatever-forever-0.0.11/whatever
# hard linking whatever/polymorphisms.py -> whatever-forever-0.0.11/whatever
# hard linking whatever4e/__init__.py -> whatever-forever-0.0.11/whatever4e
# hard linking whatever4e/chain.py -> whatever-forever-0.0.11/whatever4e
# hard linking whatever4e/class_maker.py -> whatever-forever-0.0.11/whatever4e
# hard linking whatever4e/magic.py -> whatever-forever-0.0.11/whatever4e
# hard linking whatever_forever.egg-info/PKG-INFO -> whatever-forever-0.0.11/whatever_forever.egg-info
# hard linking whatever_forever.egg-info/SOURCES.txt -> whatever-forever-0.0.11/whatever_forever.egg-info
# hard linking whatever_forever.egg-info/dependency_links.txt -> whatever-forever-0.0.11/whatever_forever.egg-info
# hard linking whatever_forever.egg-info/requires.txt -> whatever-forever-0.0.11/whatever_forever.egg-info
# hard linking whatever_forever.egg-info/top_level.txt -> whatever-forever-0.0.11/whatever_forever.egg-info
# copying setup.cfg -> whatever-forever-0.0.11
# Writing whatever-forever-0.0.11/setup.cfg
# Creating tar archive
# removing 'whatever-forever-0.0.11' (and everything under it)
# running upload
# Submitting dist/whatever-forever-0.0.11.tar.gz to https://testpypi.python.org/pypi
# Server response (200): OK
# running bdist_wheel
# running build
# running build_py
# installing to build/bdist.macosx-10.6-x86_64/wheel
# running install
# running install_lib
# creating build/bdist.macosx-10.6-x86_64/wheel
# creating build/bdist.macosx-10.6-x86_64/wheel/whatever
# copying build/lib/whatever/__init__.py -> build/bdist.macosx-10.6-x86_64/wheel/whatever
# copying build/lib/whatever/chain.py -> build/bdist.macosx-10.6-x86_64/wheel/whatever
# copying build/lib/whatever/class_maker.py -> build/bdist.macosx-10.6-x86_64/wheel/whatever
# copying build/lib/whatever/imports_for_whatever_forever.py -> build/bdist.macosx-10.6-x86_64/wheel/whatever
# copying build/lib/whatever/magic.py -> build/bdist.macosx-10.6-x86_64/wheel/whatever
# copying build/lib/whatever/polymorphisms.py -> build/bdist.macosx-10.6-x86_64/wheel/whatever
# copying build/lib/whatever/Untitled.py -> build/bdist.macosx-10.6-x86_64/wheel/whatever
# copying build/lib/whatever/Untitled1.py -> build/bdist.macosx-10.6-x86_64/wheel/whatever
# creating build/bdist.macosx-10.6-x86_64/wheel/whatever4e
# copying build/lib/whatever4e/__init__.py -> build/bdist.macosx-10.6-x86_64/wheel/whatever4e
# copying build/lib/whatever4e/chain.py -> build/bdist.macosx-10.6-x86_64/wheel/whatever4e
# copying build/lib/whatever4e/class_maker.py -> build/bdist.macosx-10.6-x86_64/wheel/whatever4e
# copying build/lib/whatever4e/magic.py -> build/bdist.macosx-10.6-x86_64/wheel/whatever4e
# running install_egg_info
# running egg_info
# writing requirements to whatever_forever.egg-info/requires.txt
# writing top-level names to whatever_forever.egg-info/top_level.txt
# writing dependency_links to whatever_forever.egg-info/dependency_links.txt
# writing whatever_forever.egg-info/PKG-INFO
# reading manifest file 'whatever_forever.egg-info/SOURCES.txt'
# reading manifest template 'MANIFEST.in'
# warning: no files found matching '*.md'
# warning: no files found matching '*.ipynb' under directory 'tests/'
# writing manifest file 'whatever_forever.egg-info/SOURCES.txt'
# Copying whatever_forever.egg-info to build/bdist.macosx-10.6-x86_64/wheel/whatever_forever-0.0.11-py3.5.egg-info
# running install_scripts
# creating build/bdist.macosx-10.6-x86_64/wheel/whatever_forever-0.0.11.dist-info/WHEEL
# running upload
# Submitting /Users/tfast/whatever-forever/dist/whatever_forever-0.0.11-py2.py3-none-any.whl to https://testpypi.python.org/pypi
# Server response (200): OK

# %% [markdown]
# # Cut a real release for PyPi

# %%
# !python setup.py register -r pypi
# !python setup.py sdist
# !python setup.py bdist_wheel
# !python setup.py sdist upload -r pypi
# !python setup.py bdist_wheel upload -r pypi
# Out:
# running register
# running egg_info
# writing top-level names to whatever_forever.egg-info/top_level.txt
# writing dependency_links to whatever_forever.egg-info/dependency_links.txt
# writing requirements to whatever_forever.egg-info/requires.txt
# writing whatever_forever.egg-info/PKG-INFO
# reading manifest file 'whatever_forever.egg-info/SOURCES.txt'
# reading manifest template 'MANIFEST.in'
# warning: no files found matching '*.md'
# warning: no files found matching '*.ipynb' under directory 'tests/'
# writing manifest file 'whatever_forever.egg-info/SOURCES.txt'
# running check
# Registering whatever-forever to https://pypi.python.org/pypi
# Server response (200): OK
# running sdist
# running egg_info
# writing requirements to whatever_forever.egg-info/requires.txt
# writing top-level names to whatever_forever.egg-info/top_level.txt
# writing whatever_forever.egg-info/PKG-INFO
# writing dependency_links to whatever_forever.egg-info/dependency_links.txt
# reading manifest file 'whatever_forever.egg-info/SOURCES.txt'
# reading manifest template 'MANIFEST.in'
# warning: no files found matching '*.md'
# warning: no files found matching '*.ipynb' under directory 'tests/'
# writing manifest file 'whatever_forever.egg-info/SOURCES.txt'
# running check
# creating whatever-forever-0.0.11
# creating whatever-forever-0.0.11/whatever
# creating whatever-forever-0.0.11/whatever4e
# creating whatever-forever-0.0.11/whatever_forever.egg-info
# making hard links in whatever-forever-0.0.11...
# hard linking Automation.ipynb -> whatever-forever-0.0.11
# hard linking LICENSE -> whatever-forever-0.0.11
# hard linking MANIFEST.in -> whatever-forever-0.0.11
# hard linking README.rst -> whatever-forever-0.0.11
# hard linking Untitled1.ipynb -> whatever-forever-0.0.11
# hard linking setup.cfg -> whatever-forever-0.0.11
# hard linking setup.py -> whatever-forever-0.0.11
# hard linking whatever/Untitled.py -> whatever-forever-0.0.11/whatever
# hard linking whatever/Untitled1.py -> whatever-forever-0.0.11/whatever
# hard linking whatever/__init__.py -> whatever-forever-0.0.11/whatever
# hard linking whatever/chain.py -> whatever-forever-0.0.11/whatever
# hard linking whatever/class_maker.py -> whatever-forever-0.0.11/whatever
# hard linking whatever/imports_for_whatever_forever.py -> whatever-forever-0.0.11/whatever
# hard linking whatever/magic.py -> whatever-forever-0.0.11/whatever
# hard linking whatever/polymorphisms.py -> whatever-forever-0.0.11/whatever
# hard linking whatever4e/__init__.py -> whatever-forever-0.0.11/whatever4e
# hard linking whatever4e/chain.py -> whatever-forever-0.0.11/whatever4e
# hard linking whatever4e/class_maker.py -> whatever-forever-0.0.11/whatever4e
# hard linking whatever4e/magic.py -> whatever-forever-0.0.11/whatever4e
# hard linking whatever_forever.egg-info/PKG-INFO -> whatever-forever-0.0.11/whatever_forever.egg-info
# hard linking whatever_forever.egg-info/SOURCES.txt -> whatever-forever-0.0.11/whatever_forever.egg-info
# hard linking whatever_forever.egg-info/dependency_links.txt -> whatever-forever-0.0.11/whatever_forever.egg-info
# hard linking whatever_forever.egg-info/requires.txt -> whatever-forever-0.0.11/whatever_forever.egg-info
# hard linking whatever_forever.egg-info/top_level.txt -> whatever-forever-0.0.11/whatever_forever.egg-info
# copying setup.cfg -> whatever-forever-0.0.11
# Writing whatever-forever-0.0.11/setup.cfg
# Creating tar archive
# removing 'whatever-forever-0.0.11' (and everything under it)
# running bdist_wheel
# running build
# running build_py
# installing to build/bdist.macosx-10.6-x86_64/wheel
# running install
# running install_lib
# creating build/bdist.macosx-10.6-x86_64/wheel
# creating build/bdist.macosx-10.6-x86_64/wheel/whatever
# copying build/lib/whatever/__init__.py -> build/bdist.macosx-10.6-x86_64/wheel/whatever
# copying build/lib/whatever/chain.py -> build/bdist.macosx-10.6-x86_64/wheel/whatever
# copying build/lib/whatever/class_maker.py -> build/bdist.macosx-10.6-x86_64/wheel/whatever
# copying build/lib/whatever/imports_for_whatever_forever.py -> build/bdist.macosx-10.6-x86_64/wheel/whatever
# copying build/lib/whatever/magic.py -> build/bdist.macosx-10.6-x86_64/wheel/whatever
# copying build/lib/whatever/polymorphisms.py -> build/bdist.macosx-10.6-x86_64/wheel/whatever
# copying build/lib/whatever/Untitled.py -> build/bdist.macosx-10.6-x86_64/wheel/whatever
# copying build/lib/whatever/Untitled1.py -> build/bdist.macosx-10.6-x86_64/wheel/whatever
# creating build/bdist.macosx-10.6-x86_64/wheel/whatever4e
# copying build/lib/whatever4e/__init__.py -> build/bdist.macosx-10.6-x86_64/wheel/whatever4e
# copying build/lib/whatever4e/chain.py -> build/bdist.macosx-10.6-x86_64/wheel/whatever4e
# copying build/lib/whatever4e/class_maker.py -> build/bdist.macosx-10.6-x86_64/wheel/whatever4e
# copying build/lib/whatever4e/magic.py -> build/bdist.macosx-10.6-x86_64/wheel/whatever4e
# running install_egg_info
# running egg_info
# writing requirements to whatever_forever.egg-info/requires.txt
# writing top-level names to whatever_forever.egg-info/top_level.txt
# writing whatever_forever.egg-info/PKG-INFO
# writing dependency_links to whatever_forever.egg-info/dependency_links.txt
# reading manifest file 'whatever_forever.egg-info/SOURCES.txt'
# reading manifest template 'MANIFEST.in'
# warning: no files found matching '*.md'
# warning: no files found matching '*.ipynb' under directory 'tests/'
# writing manifest file 'whatever_forever.egg-info/SOURCES.txt'
# Copying whatever_forever.egg-info to build/bdist.macosx-10.6-x86_64/wheel/whatever_forever-0.0.11-py3.5.egg-info
# running install_scripts
# creating build/bdist.macosx-10.6-x86_64/wheel/whatever_forever-0.0.11.dist-info/WHEEL
# running sdist
# running egg_info
# writing top-level names to whatever_forever.egg-info/top_level.txt
# writing whatever_forever.egg-info/PKG-INFO
# writing dependency_links to whatever_forever.egg-info/dependency_links.txt
# writing requirements to whatever_forever.egg-info/requires.txt
# reading manifest file 'whatever_forever.egg-info/SOURCES.txt'
# reading manifest template 'MANIFEST.in'
# warning: no files found matching '*.md'
# warning: no files found matching '*.ipynb' under directory 'tests/'
# writing manifest file 'whatever_forever.egg-info/SOURCES.txt'
# running check
# creating whatever-forever-0.0.11
# creating whatever-forever-0.0.11/whatever
# creating whatever-forever-0.0.11/whatever4e
# creating whatever-forever-0.0.11/whatever_forever.egg-info
# making hard links in whatever-forever-0.0.11...
# hard linking Automation.ipynb -> whatever-forever-0.0.11
# hard linking LICENSE -> whatever-forever-0.0.11
# hard linking MANIFEST.in -> whatever-forever-0.0.11
# hard linking README.rst -> whatever-forever-0.0.11
# hard linking Untitled1.ipynb -> whatever-forever-0.0.11
# hard linking setup.cfg -> whatever-forever-0.0.11
# hard linking setup.py -> whatever-forever-0.0.11
# hard linking whatever/Untitled.py -> whatever-forever-0.0.11/whatever
# hard linking whatever/Untitled1.py -> whatever-forever-0.0.11/whatever
# hard linking whatever/__init__.py -> whatever-forever-0.0.11/whatever
# hard linking whatever/chain.py -> whatever-forever-0.0.11/whatever
# hard linking whatever/class_maker.py -> whatever-forever-0.0.11/whatever
# hard linking whatever/imports_for_whatever_forever.py -> whatever-forever-0.0.11/whatever
# hard linking whatever/magic.py -> whatever-forever-0.0.11/whatever
# hard linking whatever/polymorphisms.py -> whatever-forever-0.0.11/whatever
# hard linking whatever4e/__init__.py -> whatever-forever-0.0.11/whatever4e
# hard linking whatever4e/chain.py -> whatever-forever-0.0.11/whatever4e
# hard linking whatever4e/class_maker.py -> whatever-forever-0.0.11/whatever4e
# hard linking whatever4e/magic.py -> whatever-forever-0.0.11/whatever4e
# hard linking whatever_forever.egg-info/PKG-INFO -> whatever-forever-0.0.11/whatever_forever.egg-info
# hard linking whatever_forever.egg-info/SOURCES.txt -> whatever-forever-0.0.11/whatever_forever.egg-info
# hard linking whatever_forever.egg-info/dependency_links.txt -> whatever-forever-0.0.11/whatever_forever.egg-info
# hard linking whatever_forever.egg-info/requires.txt -> whatever-forever-0.0.11/whatever_forever.egg-info
# hard linking whatever_forever.egg-info/top_level.txt -> whatever-forever-0.0.11/whatever_forever.egg-info
# copying setup.cfg -> whatever-forever-0.0.11
# Writing whatever-forever-0.0.11/setup.cfg
# Creating tar archive
# removing 'whatever-forever-0.0.11' (and everything under it)
# running upload
# Submitting dist/whatever-forever-0.0.11.tar.gz to https://pypi.python.org/pypi
# Server response (200): OK
# running bdist_wheel
# running build
# running build_py
# installing to build/bdist.macosx-10.6-x86_64/wheel
# running install
# running install_lib
# creating build/bdist.macosx-10.6-x86_64/wheel
# creating build/bdist.macosx-10.6-x86_64/wheel/whatever
# copying build/lib/whatever/__init__.py -> build/bdist.macosx-10.6-x86_64/wheel/whatever
# copying build/lib/whatever/chain.py -> build/bdist.macosx-10.6-x86_64/wheel/whatever
# copying build/lib/whatever/class_maker.py -> build/bdist.macosx-10.6-x86_64/wheel/whatever
# copying build/lib/whatever/imports_for_whatever_forever.py -> build/bdist.macosx-10.6-x86_64/wheel/whatever
# copying build/lib/whatever/magic.py -> build/bdist.macosx-10.6-x86_64/wheel/whatever
# copying build/lib/whatever/polymorphisms.py -> build/bdist.macosx-10.6-x86_64/wheel/whatever
# copying build/lib/whatever/Untitled.py -> build/bdist.macosx-10.6-x86_64/wheel/whatever
# copying build/lib/whatever/Untitled1.py -> build/bdist.macosx-10.6-x86_64/wheel/whatever
# creating build/bdist.macosx-10.6-x86_64/wheel/whatever4e
# copying build/lib/whatever4e/__init__.py -> build/bdist.macosx-10.6-x86_64/wheel/whatever4e
# copying build/lib/whatever4e/chain.py -> build/bdist.macosx-10.6-x86_64/wheel/whatever4e
# copying build/lib/whatever4e/class_maker.py -> build/bdist.macosx-10.6-x86_64/wheel/whatever4e
# copying build/lib/whatever4e/magic.py -> build/bdist.macosx-10.6-x86_64/wheel/whatever4e
# running install_egg_info
# running egg_info
# writing dependency_links to whatever_forever.egg-info/dependency_links.txt
# writing requirements to whatever_forever.egg-info/requires.txt
# writing whatever_forever.egg-info/PKG-INFO
# writing top-level names to whatever_forever.egg-info/top_level.txt
# reading manifest file 'whatever_forever.egg-info/SOURCES.txt'
# reading manifest template 'MANIFEST.in'
# warning: no files found matching '*.md'
# warning: no files found matching '*.ipynb' under directory 'tests/'
# writing manifest file 'whatever_forever.egg-info/SOURCES.txt'
# Copying whatever_forever.egg-info to build/bdist.macosx-10.6-x86_64/wheel/whatever_forever-0.0.11-py3.5.egg-info
# running install_scripts
# creating build/bdist.macosx-10.6-x86_64/wheel/whatever_forever-0.0.11.dist-info/WHEEL
# running upload
# Submitting /Users/tfast/whatever-forever/dist/whatever_forever-0.0.11-py2.py3-none-any.whl to https://pypi.python.org/pypi
# Server response (200): OK

# %%
# !pip install whatever-forever --upgrade --no-cache-dir
# Out:
# Requirement already up-to-date: whatever-forever in /Users/tfast/whatever-forever
# Requirement already up-to-date: toolz in /Users/tfast/anaconda/lib/python3.5/site-packages (from whatever-forever)
