# %%
from toolz.curried import pipe
from whatever4e import Forever, Chain

# %%
from yaml import safe_load
Forever.cell('yaml', safe_load, display=print)

# %% [markdown]
# ## `yaml` magic

# %%
# %%yaml data
# foo: bar
# baz: yee-haw
# Out:
# {'foo': 'bar', 'baz': 'yee-haw'}

# %%
from mistune import markdown
from jinja2 import Template
from IPython import display
Forever.cell('mistune', Template, display=lambda x: pipe(
        x.render(**globals()), markdown, display.HTML, display.display
    ))

# %% [markdown]
# ## `jinja` magic

# %%
# %%mistune
# # This is markdown
#
# It is rendered into HTML by python.
#
# It can access global variables.
#
# {% for key, value in data.items() %}* __{{key}}__ - {{value}}
# {% endfor %}
# Out:
# <h1>This is markdown</h1>
# <p>It is rendered into HTML by python.</p>
# <p>It can access global variables.</p>
# <ul>
# <li><strong>foo</strong> - bar</li>
# <li><strong>baz</strong> - yee-haw</li>
# </ul>

# %% [markdown]
# ## `jinja` alternate jinja magic

# %%
from jinja2 import Template
Forever.cell('jinja', Template, display=lambda x: pipe(
        x.render(**globals()), display.Markdown, display.display
    ))

# %%
# %%jinja
# # This markdown is rendered by the notebook in the browser
#
# It can __ALSO__ access global variables.
#
# {% for key, value in data.items() %}* __{{key}}__ - {{value}}
# {% endfor %}
# Out:
# # This markdown is rendered by the notebook in the browser
#
# It can __ALSO__ access global variables.
#
# * __foo__ - bar
# * __baz__ - yee-haw

# %%
notes = []
@Forever.line('note', display=None)
def model_width(cell):
    notes.append(cell)
    if not cell:
        return Chain(notes) | '* {}\n'.join > display.Markdown
    return model

# %%
# %note "This is a note"
# Out:
# ['"This', 'is a note"']
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-12-4bf36555efe9> in <module>()
# ----> 1 get_ipython().magic('note "This is a note"')
#
# /Users/tfast/anaconda/lib/python3.5/site-packages/IPython/core/interactiveshell.py in magic(self, arg_s)
#    2161         magic_name, _, magic_arg_s = arg_s.partition(' ')
#    2162         magic_name = magic_name.lstrip(prefilter.ESC_MAGIC)
# -> 2163         return self.run_line_magic(magic_name, magic_arg_s)
#    2164
#    2165     #-------------------------------------------------------------------------
#
# /Users/tfast/anaconda/lib/python3.5/site-packages/IPython/core/interactiveshell.py in run_line_magic(self, magic_name, line)
#    2082                 kwargs['local_ns'] = sys._getframe(stack_depth).f_locals
#    2083             with self.builtin_trap:
# -> 2084                 result = fn(*args,**kwargs)
#    2085             return result
#    2086
#
# /Users/tfast/w4e/whatever4e/magic.py in magical_line(line, f, **kwargs)
#      70     print(entries)
#      71     if len(entries) == 2:
# ---> 72         return magical_cell(*entries, f, **kwargs)
#      73     if len(entries) == 1:
#      74         return magical_cell("", entries[0], f, **kwargs)
#
# /Users/tfast/w4e/whatever4e/magic.py in magical_cell(line, cell, f, **kwargs)
#      32 )
#      33 def magical_cell(line, cell, f=identity, **kwargs):
# ---> 34     args = magic_arguments.parse_argstring(magical_cell, line.strip())
#      35     for key, value in kwargs.items():
#      36         # Set the values if they are not args
#
# /Users/tfast/anaconda/lib/python3.5/site-packages/IPython/core/magic_arguments.py in parse_argstring(magic_func, argstring)
#     162     """ Parse the string of arguments for the given magic function.
#     163     """
# --> 164     return magic_func.parser.parse_argstring(argstring)
#     165
#     166
#
# /Users/tfast/anaconda/lib/python3.5/site-packages/IPython/core/magic_arguments.py in parse_argstring(self, argstring)
#     133         """ Split a string into an argument list and parse that argument list.
#     134         """
# --> 135         argv = arg_split(argstring)
#     136         return self.parse_args(argv)
#     137
#
# /Users/tfast/anaconda/lib/python3.5/site-packages/IPython/utils/_process_common.py in arg_split(s, posix, strict)
#     200     while True:
#     201         try:
# --> 202             tokens.append(next(lex))
#     203         except StopIteration:
#     204             break
#
# /Users/tfast/anaconda/lib/python3.5/shlex.py in __next__(self)
#     261
#     262     def __next__(self):
# --> 263         token = self.get_token()
#     264         if token == self.eof:
#     265             raise StopIteration
#
# /Users/tfast/anaconda/lib/python3.5/shlex.py in get_token(self)
#      88             return tok
#      89         # No pushback.  Get a token.
# ---> 90         raw = self.read_token()
#      91         # Handle inclusions
#      92         if self.source is not None:
#
# /Users/tfast/anaconda/lib/python3.5/shlex.py in read_token(self)
#     164                         print("shlex: I see EOF in quotes state")
#     165                     # XXX what error should be raised here?
# --> 166                     raise ValueError("No closing quotation")
#     167                 if nextchar == self.state:
#     168                     if not self.posix:
#
# ValueError: No closing quotation
